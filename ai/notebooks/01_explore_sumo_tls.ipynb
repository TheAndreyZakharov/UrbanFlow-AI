# %% [markdown]
# # UrbanFlow AI — Executed SUMO and TLS Exploration
#
# Generated by `ai/notebooks/create_analysis_notebooks.py`.
#
# Generated at UTC: `2026-06-27T23:49:12.921618+00:00`
#
# Project root: `/Users/andrey/Documents/projects/UrbanFlow-AI`
#
# These notebooks are generated with embedded outputs. Code cells are hidden by default in Jupyter UI metadata.

# %% [markdown]
# ## Executed SUMO and AI artifact overview
#
# This notebook was generated with embedded outputs. It reads real generated files only.

# %%
# UrbanFlow AI generated SUMO/TLS report. Outputs are embedded by create_analysis_notebooks.py.
# Out:
# Project root: /Users/andrey/Documents/projects/UrbanFlow-AI
# Python executable: /Users/andrey/Documents/projects/UrbanFlow-AI/server/.venv/bin/python
# AI root: /Users/andrey/Documents/projects/UrbanFlow-AI/ai
# Project data dir: /Users/andrey/Documents/projects/UrbanFlow-AI/data
# Server data dir: /Users/andrey/Documents/projects/UrbanFlow-AI/server/data
#
# SUMO artifacts:
#   debug files: 1
#   net files: 1
#   route files: 1
#   latest debug: /Users/andrey/Documents/projects/UrbanFlow-AI/server/data/sumo/session_2914ad483ec74ca9a9135d87d1cef9d3/debug.txt
#   latest net: /Users/andrey/Documents/projects/UrbanFlow-AI/server/data/sumo/session_2914ad483ec74ca9a9135d87d1cef9d3/map.net.xml
#
# Training artifacts:
#   history CSV files: 3
#   history JSONL files: 3
#   summaries: 3
#   checkpoints: 3
#   snapshots: 11
#   saved models: 0
#   metadata files: 0
#   latest history CSV: /Users/andrey/Documents/projects/UrbanFlow-AI/data/models/tls_osm_only/runs/training_bb3a78c518f94d6ba0b8eecbeb528fa4/training_history.csv
#   latest summary: /Users/andrey/Documents/projects/UrbanFlow-AI/data/models/tls_osm_only/runs/training_bb3a78c518f94d6ba0b8eecbeb528fa4/latest_summary.json
#   latest checkpoint: /Users/andrey/Documents/projects/UrbanFlow-AI/data/models/tls_osm_only/runs/training_bb3a78c518f94d6ba0b8eecbeb528fa4/checkpoints/best_model.json
# Latest SUMO debug.txt <pre>net=data/sumo/session_2914ad483ec74ca9a9135d87d1cef9d3/map.net.xml
# routes=data/sumo/session_2914ad483ec74ca9a9135d87d1cef9d3/all_routes.rou.xml
# pt_stops=data/sumo/session_2914ad483ec74ca9a9135d87d1cef9d3/public_transport.add.xml
# pt_lines=data/sumo/session_2914ad483ec74ca9a9135d87d1cef9d3/public_transport_lines.xml
# pt_routes=data/sumo/session_2914ad483ec74ca9a9135d87d1cef9d3/public_transport.rou.xml
# tls_junction_count=0
# sumo_net_tls_count=512
# tls_junction_ids=
# route_vehicle_count=0
# route_flow_count=0
# route_person_count=220
# pt_stop_count=425
# pt_vehicle_count=0
# pt_flow_count=0
# pt_period_300_only=False</pre>
# Parsed latest SUMO debug metrics border="1" class="dataframe">
#
#  <tr style="text-align: right;">
#  net
#  routes
#  pt_stops
#  pt_lines
#  pt_routes
#  tls_junction_count
#  sumo_net_tls_count
#  tls_junction_ids
#  route_vehicle_count
#  route_flow_count
#  route_person_count
#  pt_stop_count
#  pt_vehicle_count
#  pt_flow_count
#  pt_period_300_only
#  file
#
#
#
#
#  data/sumo/session_2914ad483ec74ca9a9135d87d1cef9d3/map.net.xml
#  data/sumo/session_2914ad483ec74ca9a9135d87d1cef9d3/all_routes.rou.xml
#  data/sumo/session_2914ad483ec74ca9a9135d87d1cef9d3/public_transport.add.xml
#  data/sumo/session_2914ad483ec74ca9a9135d87d1cef9d3/public_transport_lines.xml
#  data/sumo/session_2914ad483ec74ca9a9135d87d1cef9d3/public_transport.rou.xml
#  0.0
#  512.0
#
#  0.0
#  0.0
#  220.0
#  425.0
#  0.0
#  0.0
#  False
#  server/data/sumo/session_2914ad483ec74ca9a9135d87d1cef9d3/debug.txt
# Top SUMO traffic lights by incoming lane complexity border="1" class="dataframe">
#
#  <tr style="text-align: right;">
#  tls_id
#  x
#  y
#  incoming_lane_count
#  incoming_edge_count
#  internal_lane_count
#  incoming_edges
#
#
#
#
#  305100744
#  731.72
#  1278.99
#  2
#  1
#  2
#  40294784#1
#
#
#  312355909
#  1119.89
#  1658.03
#  2
#  1
#  2
#  31538057
#
#
#  313798896
#  2393.59
#  4916.21
#  2
#  1
#  3
#  30433274
#
#
#  4026961639
#  2398.55
#  4948.88
#  2
#  1
#  2
#  39436799#2
#
#
#  4169789743
#  6193.16
#  5673.69
#  2
#  1
#  2
#  1219285102#0
#
#
#  10929101944
#  4532.60
#  12778.30
#  1
#  1
#  1
#  681127785
#
#
#  13605048079
#  2843.82
#  9432.12
#  1
#  1
#  1
#  75774790#0
#
#
#  273104375
#  6786.87
#  5624.40
#  1
#  1
#  4
#  531538860#2
#
#
#  273123639
#  5991.78
#  5674.93
#  1
#  1
#  2
#  25093212
#
#
#  4442634702
#  4287.39
#  8924.35
#  1
#  1
#  1
#  446842121#0
#
#
#  469261155
#  6580.88
#  3663.62
#  1
#  1
#  1
#  157316179
#
#
#  5159681564
#  6812.99
#  5635.62
#  1
#  1
#  1
#  531538860#1
#
#
#  6425738444
#  6782.07
#  5589.44
#  1
#  1
#  1
#  521148901#0
#
#
#  6427770435
#  6816.65
#  5636.28
#  1
#  1
#  1
#  531538860#0
#
#
#  6997388558
#  6511.22
#  2477.54
#  1
#  1
#  1
#  23007352#1
#
#
#  8400719320
#  6522.49
#  2479.15
#  1
#  1
#  1
#  23007352#0
#
#
#  8463626389
#  4528.79
#  12775.19
#  1
#  1
#  1
#  914312354#1
#
#
#  cluster_303346520_335381823_5948147491
#  12253.07
#  5902.06
#  1
#  1
#  5
#  629818769
# <matplotlib figure>
# <matplotlib figure>
# <matplotlib figure>
# <matplotlib figure>
# <matplotlib figure>
# SUMO TLS descriptive statistics border="1" class="dataframe">
#
#  <tr style="text-align: right;">
#  metric
#  count
#  min
#  mean
#  median
#  max
#  last
#
#
#
#
#  incoming_lane_count
#  512
#  1.0
#  4.474609
#  4.0
#  16.0
#  4.0
#
#
#  incoming_edge_count
#  512
#  1.0
#  1.591797
#  1.0
#  10.0
#  2.0
#
#
#  internal_lane_count
#  512
#  1.0
#  4.783203
#  4.0
#  39.0
#  4.0
# Local model registry and checkpoint files border="1" class="dataframe">
#
#  <tr style="text-align: right;">
#  file
#  kind
#  model_type
#  model_version
#  signal_scope
#  current_step
#  best_reward
#  latest_reward
#  average_wait_time
#  congestion_score
#  stopped_vehicles
#  label
#  path
#
#
#
#
#  data/models/tls_all_intersections/runs/training_b7575e6037c244f19a100360304c757f/snapshots/checkpoint_step_00000000.json
#  snapshot
#  UrbanFlowTlsPolicy
#  urbanflow_tls_v1
#  all_intersections
#  NaN
#  NaN
#  NaN
#  NaN
#  NaN
#  NaN
#  None
#  None
#
#
#  data/models/tls_all_intersections/runs/training_b7575e6037c244f19a100360304c757f/snapshots/checkpoint_step_00000001.json
#  snapshot
#  UrbanFlowTlsPolicy
#  urbanflow_tls_v1
#  all_intersections
#  1.0
#  7649.510708
#  7649.510708
#  0.04
#  0.038
#  19.0
#  None
#  None
#
#
#  data/models/tls_all_intersections/runs/training_b7575e6037c244f19a100360304c757f/checkpoints/best_model.json
#  checkpoint
#  UrbanFlowTlsPolicy
#  urbanflow_tls_v1
#  all_intersections
#  120.0
#  7649.510708
#  4165.593993
#  0.70
#  0.704
#  352.0
#  None
#  None
#
#
#  data/models/tls_all_intersections/runs/training_b7575e6037c244f19a100360304c757f/snapshots/checkpoint_step_00000120.json
#  snapshot
#  UrbanFlowTlsPolicy
#  urbanflow_tls_v1
#  all_intersections
#  120.0
#  7649.510708
#  4165.593993
#  0.70
#  0.704
#  352.0
#  None
#  None
#
#
#  data/models/tls_all_intersections/runs/training_b7575e6037c244f19a100360304c757f/latest_summary.json
#  latest_summary
#  NaN
#  NaN
#  all_intersections
#  160.0
#  7649.510708
#  3456.995972
#  0.80
#  0.798
#  411.0
#  None
#  None
#
#
#  data/models/tls_all_intersections/runs/training_b7575e6037c244f19a100360304c757f/job.json
#  json
#  NaN
#  NaN
#  all_intersections
#  169.0
#  7649.510708
#  3828.090189
#  0.75
#  0.746
#  387.0
#  None
#  None
#
#
#  data/models/tls_all_intersections/runs/training_a6b0c2e57ec441ab9999a3fefb776b11/snapshots/checkpoint_step_00000000.json
#  snapshot
#  UrbanFlowTlsPolicy
#  urbanflow_tls_v1
#  all_intersections
#  NaN
#  NaN
#  NaN
#  NaN
#  NaN
#  NaN
#  None
#  None
#
#
#  data/models/tls_all_intersections/runs/training_a6b0c2e57ec441ab9999a3fefb776b11/snapshots/checkpoint_step_00000001.json
#  snapshot
#  UrbanFlowTlsPolicy
#  urbanflow_tls_v1
#  all_intersections
#  1.0
#  1582.550786
#  1582.550786
#  NaN
#  NaN
#  NaN
#  None
#  None
#
#
#  data/models/tls_all_intersections/runs/training_a6b0c2e57ec441ab9999a3fefb776b11/snapshots/checkpoint_step_00000120.json
#  snapshot
#  UrbanFlowTlsPolicy
#  urbanflow_tls_v1
#  all_intersections
#  120.0
#  1582.550786
#  1365.636915
#  0.45
#  0.450
#  27.0
#  None
#  None
#
#
#  data/models/tls_all_intersections/runs/training_a6b0c2e57ec441ab9999a3fefb776b11/snapshots/checkpoint_step_00000240.json
#  snapshot
#  UrbanFlowTlsPolicy
#  urbanflow_tls_v1
#  all_intersections
#  240.0
#  1582.550786
#  1348.710787
#  0.44
#  0.443
#  31.0
#  None
#  None
#
#
#  data/models/tls_all_intersections/runs/training_a6b0c2e57ec441ab9999a3fefb776b11/snapshots/checkpoint_step_00000360.json
#  snapshot
#  UrbanFlowTlsPolicy
#  urbanflow_tls_v1
#  all_intersections
#  360.0
#  1582.550786
#  1263.972213
#  0.64
#  0.640
#  48.0
#  None
#  None
#
#
#  data/models/tls_all_intersections/runs/training_a6b0c2e57ec441ab9999a3fefb776b11/checkpoints/best_model.json
#  checkpoint
#  UrbanFlowTlsPolicy
#  urbanflow_tls_v1
#  all_intersections
#  480.0
#  1582.550786
#  1275.669588
#  0.58
#  0.575
#  42.0
#  None
#  None
#
#
#  data/models/tls_all_intersections/runs/training_a6b0c2e57ec441ab9999a3fefb776b11/snapshots/checkpoint_step_00000480.json
#  snapshot
#  UrbanFlowTlsPolicy
#  urbanflow_tls_v1
#  all_intersections
#  480.0
#  1582.550786
#  1275.669588
#  0.58
#  0.575
#  42.0
#  None
#  None
#
#
#  data/models/tls_all_intersections/runs/training_a6b0c2e57ec441ab9999a3fefb776b11/latest_summary.json
#  latest_summary
#  NaN
#  NaN
#  all_intersections
#  590.0
#  1582.550786
#  1237.198069
#  0.65
#  0.653
#  49.0
#  None
#  None
#
#
#  data/models/tls_all_intersections/runs/training_a6b0c2e57ec441ab9999a3fefb776b11/job.json
#  json
#  NaN
#  NaN
#  all_intersections
#  590.0
#  1582.550786
#  1237.198069
#  0.65
#  0.653
#  49.0
#  None
#  None
#
#
#  data/models/tls_osm_only/runs/training_bb3a78c518f94d6ba0b8eecbeb528fa4/snapshots/checkpoint_step_00000000.json
#  snapshot
#  UrbanFlowTlsPolicy
#  urbanflow_tls_v1
#  osm_only
#  NaN
#  NaN
#  NaN
#  NaN
#  NaN
#  NaN
#  None
#  None
#
#
#  data/models/tls_osm_only/runs/training_bb3a78c518f94d6ba0b8eecbeb528fa4/checkpoints/best_model.json
#  checkpoint
#  UrbanFlowTlsPolicy
#  urbanflow_tls_v1
#  osm_only
#  1.0
#  1928.548345
#  1928.548345
#  0.02
#  0.017
#  5.0
#  None
#  None
#
#
#  data/models/tls_osm_only/runs/training_bb3a78c518f94d6ba0b8eecbeb528fa4/snapshots/checkpoint_step_00000001.json
#  snapshot
#  UrbanFlowTlsPolicy
#  urbanflow_tls_v1
#  osm_only
#  1.0
#  1928.548345
#  1928.548345
#  0.02
#  0.017
#  5.0
#  None
#  None
#
#
#  data/models/tls_osm_only/runs/training_bb3a78c518f94d6ba0b8eecbeb528fa4/job.json
#  json
#  NaN
#  NaN
#  osm_only
#  39.0
#  1928.548345
#  706.877075
#  0.50
#  0.500
#  150.0
#  None
#  None
#
#
#  data/models/tls_osm_only/runs/training_bb3a78c518f94d6ba0b8eecbeb528fa4/latest_summary.json
#  latest_summary
#  NaN
#  NaN
#  osm_only
#  40.0
#  1928.548345
#  694.437690
#  0.50
#  0.503
#  151.0
#  None
#  None
# Latest AI training history border="1" class="dataframe">
#
#  <tr style="text-align: right;">
#  job_id
#  session_id
#  signal_scope
#  current_step
#  current_episode
#  current_vehicles
#  best_reward
#  latest_reward
#  average_wait_time
#  congestion_score
#  stopped_vehicles
#  checkpoint_path
#  model_output_dir
#  created_at_utc
#
#
#
#
#  training:bb3a78c518f94d6ba0b8eecbeb528fa4
#  session:2914ad483ec74ca9a9135d87d1cef9d3
#  osm_only
#  0.0
#  0.0
#  300.0
#  NaN
#  NaN
#  0.00
#  0.000
#  0.0
#  /Users/andrey/Documents/projects/UrbanFlow-AI/data/models/tls_osm_only/runs/training_bb3a78c518f94d6ba0b8eecbeb528fa4/checkpoints/best_model.json
#  /Users/andrey/Documents/projects/UrbanFlow-AI/data/models/tls_osm_only/runs/training_bb3a78c518f94d6ba0b8eecbeb528fa4
#  2026-06-27T23:45:14.274888+00:00
#
#
#  training:bb3a78c518f94d6ba0b8eecbeb528fa4
#  session:2914ad483ec74ca9a9135d87d1cef9d3
#  osm_only
#  1.0
#  0.0
#  300.0
#  1928.548345
#  1928.548345
#  0.02
#  0.017
#  5.0
#  /Users/andrey/Documents/projects/UrbanFlow-AI/data/models/tls_osm_only/runs/training_bb3a78c518f94d6ba0b8eecbeb528fa4/checkpoints/best_model.json
#  /Users/andrey/Documents/projects/UrbanFlow-AI/data/models/tls_osm_only/runs/training_bb3a78c518f94d6ba0b8eecbeb528fa4
#  2026-06-27T23:45:31.766852+00:00
#
#
#  training:bb3a78c518f94d6ba0b8eecbeb528fa4
#  session:2914ad483ec74ca9a9135d87d1cef9d3
#  osm_only
#  10.0
#  0.0
#  300.0
#  1928.548345
#  1520.880017
#  0.18
#  0.177
#  53.0
#  /Users/andrey/Documents/projects/UrbanFlow-AI/data/models/tls_osm_only/runs/training_bb3a78c518f94d6ba0b8eecbeb528fa4/checkpoints/best_model.json
#  /Users/andrey/Documents/projects/UrbanFlow-AI/data/models/tls_osm_only/runs/training_bb3a78c518f94d6ba0b8eecbeb528fa4
#  2026-06-27T23:46:12.592703+00:00
#
#
#  training:bb3a78c518f94d6ba0b8eecbeb528fa4
#  session:2914ad483ec74ca9a9135d87d1cef9d3
#  osm_only
#  20.0
#  0.0
#  300.0
#  1928.548345
#  1198.928521
#  0.33
#  0.330
#  99.0
#  /Users/andrey/Documents/projects/UrbanFlow-AI/data/models/tls_osm_only/runs/training_bb3a78c518f94d6ba0b8eecbeb528fa4/checkpoints/best_model.json
#  /Users/andrey/Documents/projects/UrbanFlow-AI/data/models/tls_osm_only/runs/training_bb3a78c518f94d6ba0b8eecbeb528fa4
#  2026-06-27T23:47:16.453942+00:00
#
#
#  training:bb3a78c518f94d6ba0b8eecbeb528fa4
#  session:2914ad483ec74ca9a9135d87d1cef9d3
#  osm_only
#  30.0
#  0.0
#  300.0
#  1928.548345
#  950.891997
#  0.40
#  0.403
#  121.0
#  /Users/andrey/Documents/projects/UrbanFlow-AI/data/models/tls_osm_only/runs/training_bb3a78c518f94d6ba0b8eecbeb528fa4/checkpoints/best_model.json
#  /Users/andrey/Documents/projects/UrbanFlow-AI/data/models/tls_osm_only/runs/training_bb3a78c518f94d6ba0b8eecbeb528fa4
#  2026-06-27T23:48:13.610278+00:00
#
#
#  training:bb3a78c518f94d6ba0b8eecbeb528fa4
#  session:2914ad483ec74ca9a9135d87d1cef9d3
#  osm_only
#  40.0
#  0.0
#  300.0
#  1928.548345
#  694.437690
#  0.50
#  0.503
#  151.0
#  /Users/andrey/Documents/projects/UrbanFlow-AI/data/models/tls_osm_only/runs/training_bb3a78c518f94d6ba0b8eecbeb528fa4/checkpoints/best_model.json
#  /Users/andrey/Documents/projects/UrbanFlow-AI/data/models/tls_osm_only/runs/training_bb3a78c518f94d6ba0b8eecbeb528fa4
#  2026-06-27T23:49:08.632833+00:00
# <matplotlib figure>
# <matplotlib figure>
