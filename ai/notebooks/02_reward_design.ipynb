# %% [markdown]
# # UrbanFlow AI — Executed Reward Design Laboratory
#
# Generated by `ai/notebooks/create_analysis_notebooks.py`.
#
# Generated at UTC: `2026-06-27T23:49:15.531038+00:00`
#
# Project root: `/Users/andrey/Documents/projects/UrbanFlow-AI`
#
# These notebooks are generated with embedded outputs. Code cells are hidden by default in Jupyter UI metadata.

# %% [markdown]
# ## Executed reward and policy analysis
#
# This notebook combines deterministic reward analysis with real UrbanFlow AI training artifacts.

# %%
# UrbanFlow AI generated reward-design report. Outputs are embedded by create_analysis_notebooks.py.
# Out:
# Reward weights > queue wait_time stopped congestion low_speed switch_penalty emergency_bonus throughput_bonus 2.6000 0.0950 2.2000 5.0000 0.4500 1.4000 3.0000 0.2500
# Policy pressure weights > halted vehicles waiting_time occupancy low_speed downstream_penalty emergency 3.0000 1.0000 0.0400 1.6000 0.6500 0.3500 7.0000
# Reward sensitivity table border="1" class="dataframe">
#
#  <tr style="text-align: right;">
#  scenario
#  halted
#  waiting_time
#  congestion
#  switches
#  reward
#
#
#
#
#  halted=0
#  0
#  0
#  0
#  0
#  2.50
#
#
#  halted=2
#  2
#  0
#  0
#  0
#  -7.10
#
#
#  halted=5
#  5
#  0
#  0
#  0
#  -21.50
#
#
#  halted=10
#  10
#  0
#  0
#  0
#  -45.50
#
#
#  halted=20
#  20
#  0
#  0
#  0
#  -93.50
#
#
#  halted=40
#  40
#  0
#  0
#  0
#  -189.50
#
#
#  waiting_time=0
#  0
#  0
#  0
#  0
#  2.50
#
#
#  waiting_time=30
#  0
#  30
#  0
#  0
#  -0.35
#
#
#  waiting_time=60
#  0
#  60
#  0
#  0
#  -3.20
#
#
#  waiting_time=120
#  0
#  120
#  0
#  0
#  -8.90
#
#
#  waiting_time=300
#  0
#  300
#  0
#  0
#  -26.00
#
#
#  waiting_time=600
#  0
#  600
#  0
#  0
#  -54.50
#
#
#  congestion=0
#  0
#  0
#  0
#  0
#  2.50
#
#
#  congestion=1
#  0
#  0
#  1
#  0
#  -2.50
#
#
#  congestion=2
#  0
#  0
#  2
#  0
#  -7.50
#
#
#  congestion=5
#  0
#  0
#  5
#  0
#  -22.50
#
#
#  congestion=10
#  0
#  0
#  10
#  0
#  -47.50
#
#
#  congestion=20
#  0
#  0
#  20
#  0
#  -97.50
#
#
#  switches=0
#  0
#  0
#  0
#  0
#  2.50
#
#
#  switches=1
#  0
#  0
#  0
#  1
#  1.10
#
#
#  switches=2
#  0
#  0
#  0
#  2
#  -0.30
#
#
#  switches=5
#  0
#  0
#  0
#  5
#  -4.50
#
#
#  switches=10
#  0
#  0
#  0
#  10
#  -11.50
#
#
#  switches=20
#  0
#  0
#  0
#  20
#  -25.50
# <matplotlib figure>
# <matplotlib figure>
# <matplotlib figure>
# <matplotlib figure>
# <matplotlib figure>
# Traffic-light phase pressure examples border="1" class="dataframe">
#
#  <tr style="text-align: right;">
#  phase
#  halted
#  vehicles
#  waiting_time
#  occupancy
#  low_speed
#  emergency
#  pressure
#
#
#
#
#  empty approach
#  0
#  0
#  0
#  0.0
#  0
#  0
#  0.00
#
#
#  moving traffic
#  0
#  12
#  15
#  0.3
#  1
#  0
#  13.73
#
#
#  short queue
#  4
#  10
#  60
#  0.4
#  4
#  0
#  27.64
#
#
#  long queue
#  18
#  25
#  260
#  0.9
#  18
#  0
#  102.54
#
#
#  emergency approach
#  2
#  6
#  30
#  0.2
#  2
#  1
#  21.82
# <matplotlib figure>
# Real latest training history border="1" class="dataframe">
#
#  <tr style="text-align: right;">
#  job_id
#  session_id
#  signal_scope
#  current_step
#  current_episode
#  current_vehicles
#  best_reward
#  latest_reward
#  average_wait_time
#  congestion_score
#  stopped_vehicles
#  checkpoint_path
#  model_output_dir
#  created_at_utc
#
#
#
#
#  training:bb3a78c518f94d6ba0b8eecbeb528fa4
#  session:2914ad483ec74ca9a9135d87d1cef9d3
#  osm_only
#  0.0
#  0.0
#  300.0
#  NaN
#  NaN
#  0.00
#  0.000
#  0.0
#  /Users/andrey/Documents/projects/UrbanFlow-AI/data/models/tls_osm_only/runs/training_bb3a78c518f94d6ba0b8eecbeb528fa4/checkpoints/best_model.json
#  /Users/andrey/Documents/projects/UrbanFlow-AI/data/models/tls_osm_only/runs/training_bb3a78c518f94d6ba0b8eecbeb528fa4
#  2026-06-27T23:45:14.274888+00:00
#
#
#  training:bb3a78c518f94d6ba0b8eecbeb528fa4
#  session:2914ad483ec74ca9a9135d87d1cef9d3
#  osm_only
#  1.0
#  0.0
#  300.0
#  1928.548345
#  1928.548345
#  0.02
#  0.017
#  5.0
#  /Users/andrey/Documents/projects/UrbanFlow-AI/data/models/tls_osm_only/runs/training_bb3a78c518f94d6ba0b8eecbeb528fa4/checkpoints/best_model.json
#  /Users/andrey/Documents/projects/UrbanFlow-AI/data/models/tls_osm_only/runs/training_bb3a78c518f94d6ba0b8eecbeb528fa4
#  2026-06-27T23:45:31.766852+00:00
#
#
#  training:bb3a78c518f94d6ba0b8eecbeb528fa4
#  session:2914ad483ec74ca9a9135d87d1cef9d3
#  osm_only
#  10.0
#  0.0
#  300.0
#  1928.548345
#  1520.880017
#  0.18
#  0.177
#  53.0
#  /Users/andrey/Documents/projects/UrbanFlow-AI/data/models/tls_osm_only/runs/training_bb3a78c518f94d6ba0b8eecbeb528fa4/checkpoints/best_model.json
#  /Users/andrey/Documents/projects/UrbanFlow-AI/data/models/tls_osm_only/runs/training_bb3a78c518f94d6ba0b8eecbeb528fa4
#  2026-06-27T23:46:12.592703+00:00
#
#
#  training:bb3a78c518f94d6ba0b8eecbeb528fa4
#  session:2914ad483ec74ca9a9135d87d1cef9d3
#  osm_only
#  20.0
#  0.0
#  300.0
#  1928.548345
#  1198.928521
#  0.33
#  0.330
#  99.0
#  /Users/andrey/Documents/projects/UrbanFlow-AI/data/models/tls_osm_only/runs/training_bb3a78c518f94d6ba0b8eecbeb528fa4/checkpoints/best_model.json
#  /Users/andrey/Documents/projects/UrbanFlow-AI/data/models/tls_osm_only/runs/training_bb3a78c518f94d6ba0b8eecbeb528fa4
#  2026-06-27T23:47:16.453942+00:00
#
#
#  training:bb3a78c518f94d6ba0b8eecbeb528fa4
#  session:2914ad483ec74ca9a9135d87d1cef9d3
#  osm_only
#  30.0
#  0.0
#  300.0
#  1928.548345
#  950.891997
#  0.40
#  0.403
#  121.0
#  /Users/andrey/Documents/projects/UrbanFlow-AI/data/models/tls_osm_only/runs/training_bb3a78c518f94d6ba0b8eecbeb528fa4/checkpoints/best_model.json
#  /Users/andrey/Documents/projects/UrbanFlow-AI/data/models/tls_osm_only/runs/training_bb3a78c518f94d6ba0b8eecbeb528fa4
#  2026-06-27T23:48:13.610278+00:00
#
#
#  training:bb3a78c518f94d6ba0b8eecbeb528fa4
#  session:2914ad483ec74ca9a9135d87d1cef9d3
#  osm_only
#  40.0
#  0.0
#  300.0
#  1928.548345
#  694.437690
#  0.50
#  0.503
#  151.0
#  /Users/andrey/Documents/projects/UrbanFlow-AI/data/models/tls_osm_only/runs/training_bb3a78c518f94d6ba0b8eecbeb528fa4/checkpoints/best_model.json
#  /Users/andrey/Documents/projects/UrbanFlow-AI/data/models/tls_osm_only/runs/training_bb3a78c518f94d6ba0b8eecbeb528fa4
#  2026-06-27T23:49:08.632833+00:00
# <matplotlib figure>
# Latest checkpoint summary <pre>{
#  &quot;model_type&quot;: &quot;UrbanFlowTlsPolicy&quot;,
#  &quot;model_version&quot;: &quot;urbanflow_tls_v1&quot;,
#  &quot;training_steps&quot;: 1,
#  &quot;best_reward&quot;: 1928.5483451409773,
#  &quot;config&quot;: {
#  &quot;runtime&quot;: {
#  &quot;min_green_ticks&quot;: 12,
#  &quot;max_green_ticks&quot;: 45,
#  &quot;min_yellow_ticks&quot;: 3,
#  &quot;action_interval_ticks&quot;: 3,
#  &quot;switch_margin&quot;: 4.0,
#  &quot;max_controlled_lanes_per_tls&quot;: 64,
#  &quot;model_version&quot;: &quot;urbanflow_tls_v1&quot;
#  },
#  &quot;policy&quot;: {
#  &quot;halted&quot;: 3.0,
#  &quot;vehicles&quot;: 1.0,
#  &quot;waiting_time&quot;: 0.04,
#  &quot;occupancy&quot;: 1.6,
#  &quot;low_speed&quot;: 0.65,
#  &quot;downstream_penalty&quot;: 0.35,
#  &quot;emergency&quot;: 7.0
#  },
#  &quot;reward&quot;: {
#  &quot;queue&quot;: 2.6,
#  &quot;wait_time&quot;: 0.095,
#  &quot;stopped&quot;: 2.2,
#  &quot;congestion&quot;: 5.0,
#  &quot;low_speed&quot;: 0.45,
#  &quot;switch_penalty&quot;: 1.4,
#  &quot;emergency_bonus&quot;: 3.0,
#  &quot;throughput_bonus&quot;: 0.25
#  }
#  },
#  &quot;metadata&quot;: {},
#  &quot;runtime&quot;: {
#  &quot;controlled_tls&quot;: 515,
#  &quot;last_reward&quot;: 1928.5483451409773,
#  &quot;last_tick&quot;: 1,
#  &quot;last_switches&quot;: 0
#  },
#  &quot;loaded_model_path&quot;: null,
#  &quot;job_id&quot;: &quot;training:bb3a78c518f94d6ba0b8eecbeb528fa4&quot;,
#  &quot;session_id&quot;: &quot;session:2914ad483ec74ca9a9135d87d1cef9d3&quot;,
#  &quot;signal_scope&quot;: &quot;osm_only&quot;,
#  &quot;current_step&quot;: 1,
#  &quot;current_episode&quot;: 0,
#  &quot;current_vehicles&quot;: 300,
#  &quot;latest_reward&quot;: 1928.5483451409773,
#  &quot;average_wait_time&quot;: 0.02,
#  &quot;congestion_score&quot;: 0.017,
#  &quot;stopped_vehicles&quot;: 5,
#  &quot;created_at_utc&quot;: &quot;2026-06-27T23:45:31.765507+00:00&quot;
# }</pre>
